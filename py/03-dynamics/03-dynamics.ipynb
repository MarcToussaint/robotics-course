# %%
# %matplotlib inline
import matplotlib
import numpy as np
from numpy.linalg import inv
import matplotlib.pyplot as plt
import sys
sys.path.append('../../ry')
import libry as lry
import time
import copy

# %%
# Load config, file and viewer
K = lry.Config()
K.clear();
K.addFile('pegArm.ors')
K.sortFrames();
D = K.view()

# %%
# Initialize variables, set start state
noise = .01
gravity = True
n = K.getJointDimension()
tau = .01
N = 500
T = N*tau

q, qdot = K.getJointState_qdot()
q = np.zeros(n) + 0.4
qdot = np.zeros(n)
K.setJointState_qdot(q, qdot)

q_goal = np.zeros(n)
q0 = copy.deepcopy(q)

q_hist = np.zeros((N, n))

# %%
for i in range(N):
    t = i * tau
    u = np.zeros(n)  # no controller torques

    # b) compute desired position, velocity and acceleration with sine motion profile
    
    
    # c) PD controller
    
    
    # d) PID controller
    
    
    # e) Inverse dynamics feedforward control
    M, F = K.equationOfMotion(gravity);

    
    
    # dynamic simulation (simple Euler integration of the system dynamics, look into the code)
    K.stepDynamics(u, tau, noise, gravity);
    time.sleep(tau)
    q, qdot = K.getJointState_qdot()
    print (" t=" + str(t) + "sec E=" + str(K.getEnergy()) + "  q = " + str(q))
    q_hist[i] = q

# %%
# plot q
plt.plot(q_hist)
plt.show()
